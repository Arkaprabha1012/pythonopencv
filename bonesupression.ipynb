# %% [markdown]
# <a href="https://colab.research.google.com/github/Arkaprabha1012/pythonopencv/blob/main/bonesupression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.fftpack import dct, idct

# implement 2D DCT
def dct2(a):
    return dct(dct(a.T, norm='ortho').T, norm='ortho')

# implement 2D IDCT
def idct2(a):
    return idct(idct(a.T, norm='ortho').T, norm='ortho')    

from skimage.io import imread
from skimage.color import rgb2gray
import numpy as np
import matplotlib.pylab as plt

# read lena RGB image and convert to grayscale
im = rgb2gray(imread('input.png')) 
imF = dct2(im)
im1 = idct2(imF)

# check if the reconstructed image is nearly equal to the original image
np.allclose(im, im1)
# True

# plot original and reconstructed images with matplotlib.pylab
plt.gray()
plt.subplot(121), plt.imshow(im), plt.axis('off'), plt.title('original image', size=20)
plt.subplot(122), plt.imshow(im1), plt.axis('off'), plt.title('reconstructed image (DCT+IDCT)', size=20)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

import pywt
import pywt.data
import cv2
from PIL import Image

# Load image
original = cv2.imread("input.png",0)
# Wavelet transform of image, and plot approximation and details
titles = ['Approximation', ' Horizontal detail',
          'Vertical detail', 'Diagonal detail']
coeffs2 = pywt.dwt2(original, 'bior1.3')
LL, (LH, HL, HH) = coeffs2
fig = plt.figure(figsize=(10, 3))
original1=original.resize((130,130))
#orig1=original1-LH
for i, a in enumerate([LL, LH, HL, HH]):
    ax = fig.add_subplot(1, 4, i + 1)
    ax.imshow(a, interpolation="nearest", cmap=plt.cm.gray)
    ax.set_title(titles[i], fontsize=10)
    ax.set_xticks([])
    ax.set_yticks([])

fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import ndimage
import cv2
def plot(data, title):
    plot.i += 1
    plt.subplot(2,2,plot.i)
    plt.imshow(data)
    plt.gray()
    plt.title(title)
plot.i = 0

# Load the data...
im = Image.open('input.png')
data = np.array(im, dtype=float)
plot(data, 'Original')

# A very simple and very narrow highpass filter
kernel = np.array([[-1, -1, -1],
                   [-1,  5, -1],
                   [-1, -1, -1]])
highpass_3x3 = ndimage.convolve(data, kernel)
plot(highpass_3x3, 'Simple 3x3 Highpass')

# A slightly "wider", but sill very simple highpass filter 
kernel = np.array([[-1, -1, -1, -1, -1],
                   [-1,  1,  2,  1, -1],
                   [-1,  2,  4,  2, -1],
                   [-1,  1,  2,  1, -1],
                   [-1, -1, -1, -1, -1]])
highpass_5x5 = ndimage.convolve(data, kernel)
plot(highpass_5x5, 'Simple 5x5 Highpass')

# Another way of making a highpass filter is to simply subtract a lowpass
# filtered image from the original. Here, we'll use a simple gaussian filter
# to "blur" (i.e. a lowpass filter) the original.
lowpass = ndimage.gaussian_filter(data, 3)
gauss_highpass = data - lowpass
plot(gauss_highpass, r'Gaussian Highpass, $\sigma = 3 pixels$')

plt.show()

# %%
# !unzip ML-BoneSuppression-master.zip
# Out:
# Archive:  ML-BoneSuppression-master.zip
# 0f9de5ff4cc1f793e27f9db52af35e631614a4c1
#    creating: ML-BoneSuppression-master/
#   inflating: ML-BoneSuppression-master/.DS_Store
#   inflating: ML-BoneSuppression-master/.gitignore
#   inflating: ML-BoneSuppression-master/LICENSE
#   inflating: ML-BoneSuppression-master/README.md
#    creating: ML-BoneSuppression-master/config/
#   inflating: ML-BoneSuppression-master/config/data_preprocessing.cfg
#   inflating: ML-BoneSuppression-master/config/train.cfg
#   inflating: ML-BoneSuppression-master/description.png
#   inflating: ML-BoneSuppression-master/model.py
#    creating: ML-BoneSuppression-master/model/
#   inflating: ML-BoneSuppression-master/model/model.data-00000-of-00001
#   inflating: ML-BoneSuppression-master/model/model.index
#   inflating: ML-BoneSuppression-master/model/model.meta
#  extracting: ML-BoneSuppression-master/output.png
#   inflating: ML-BoneSuppression-master/preprocessing.py
#   inflating: ML-BoneSuppression-master/requirements.txt
#  extracting: ML-BoneSuppression-master/test.png
#   inflating: ML-BoneSuppression-master/test.py
#   inflating: ML-BoneSuppression-master/train.py
#   inflating: ML-BoneSuppression-master/utils.py

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.models import Sequential

import numpy as np
import matplotlib.pyplot as plt

import os
import cv2
from keras.preprocessing.image import img_to_array

# x is noisy data and y is clean data
SIZE = 320

from tqdm import tqdm
noisy_data=[]
path1 = 'sandstone/noisy_images/'
files=os.listdir(path1)
for i in tqdm(files):
    img=cv2.imread(path1+'/'+i,0)   #Change 0 to 1 for color images
    img=cv2.resize(img,(SIZE, SIZE))
    noisy_data.append(img_to_array(img))
    

clean_data=[]
path2 = 'sandstone/clean_images/'
files=os.listdir(path2)
for i in tqdm(files):
    img=cv2.imread(path2+'/'+i,0)  #Change 0 to 1 for color images
    img=cv2.resize(img,(SIZE, SIZE))
    clean_data.append(img_to_array(img))

noisy_train = np.reshape(noisy_data, (len(noisy_data), SIZE, SIZE, 1))
noisy_train = noisy_train.astype('float32') / 255.

clean_train = np.reshape(clean_data, (len(clean_data), SIZE, SIZE, 1))
clean_train = clean_train.astype('float32') / 255.


#Displaying images with noise
plt.figure(figsize=(10, 2))
for i in range(1,4):
    ax = plt.subplot(1, 4, i)
    plt.imshow(noisy_train[i].reshape(SIZE, SIZE), cmap="binary")
plt.show()

#Displaying clean images
plt.figure(figsize=(10, 2))
for i in range(1,4):
    ax = plt.subplot(1, 4, i)
    plt.imshow(clean_train[i].reshape(SIZE, SIZE), cmap="binary")
plt.show()



model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(SIZE, SIZE, 1)))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
 

model.add(MaxPooling2D((2, 2), padding='same'))
     
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(1, (3, 3), activation='relu', padding='same'))

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

model.summary()

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(noisy_train, clean_train, 
                                                    test_size = 0.20, random_state = 0)


model.fit(x_train, y_train, epochs=10, batch_size=8, shuffle=True, verbose = 1,
          validation_split = 0.1)


print("Test_Accuracy: {:.2f}%".format(model.evaluate(np.array(x_test), np.array(y_test))[1]*100))


model.save('denoising_autoencoder.model')

no_noise_img = model.predict(x_test)


plt.imshow(no_noise_img[i].reshape(SIZE,SIZE), cmap="gray")
#plt.imsave('sandstone/denoised_images/denoised_image.tif', no_noise_img[3].reshape(SIZE,SIZE))

"""
plt.figure(figsize=(40, 4))
for i in range(10):
    # display original
    ax = plt.subplot(3, 20, i + 1)
    plt.imshow(y_test[i].reshape(SIZE,SIZE), cmap="gray")
    
    # display reconstructed (after noise removed) image
    ax = plt.subplot(3, 20, 40 +i+ 1)
    plt.imshow(no_noise_img[i].reshape(SIZE,SIZE), cmap="gray")
plt.show()

# %%
from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-8b59c9b8-df34-44ed-b161-3cd7db63118d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8b59c9b8-df34-44ed-b161-3cd7db63118d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"arkaprabha1012","key":"22f1c94f5997407eeaf192b3911476d6"}'}

# %%
! mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
! cp kaggle.json ~/.kaggle/

# %%
 ! chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d hmchuong/xray-bone-shadow-supression
# Out:
# Downloading xray-bone-shadow-supression.zip to /content
# 100% 5.23G/5.23G [01:49<00:00, 32.6MB/s]
# 100% 5.23G/5.23G [01:49<00:00, 51.2MB/s]

# %%
# !unzip xray-bone-shadow-supression.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: augmented/augmented/source/8_136.png
#   inflating: augmented/augmented/source/8_137.png
#   inflating: augmented/augmented/source/8_138.png
#   inflating: augmented/augmented/source/8_139.png
#   inflating: augmented/augmented/source/8_14.png
#   inflating: augmented/augmented/source/8_140.png
#   inflating: augmented/augmented/source/8_141.png
#   inflating: augmented/augmented/source/8_142.png
#   inflating: augmented/augmented/source/8_143.png
#   inflating: augmented/augmented/source/8_144.png
#   inflating: augmented/augmented/source/8_145.png
#   inflating: augmented/augmented/source/8_146.png
#   inflating: augmented/augmented/source/8_147.png
#   inflating: augmented/augmented/source/8_148.png
#   inflating: augmented/augmented/source/8_149.png
#   inflating: augmented/augmented/source/8_15.png
#   inflating: augmented/augmented/source/8_150.png
#   inflating: augmented/augmented/source/8_151.png
#   inflating: augmented/augmented/source/8_152.png
#   inflating: augmented/augmented/source/8_153.png
#   inflating: augmented/augmented/source/8_154.png
#   inflating: augmented/augmented/source/8_155.png
#   inflating: augmented/augmented/source/8_156.png
#   inflating: augmented/augmented/source/8_157.png
#   inflating: augmented/augmented/source/8_158.png
#   inflating: augmented/augmented/source/8_159.png
#   inflating: augmented/augmented/source/8_16.png
#   inflating: augmented/augmented/source/8_160.png
#   inflating: augmented/augmented/source/8_161.png
#   inflating: augmented/augmented/source/8_162.png
#   inflating: augmented/augmented/source/8_163.png
#   inflating: augmented/augmented/source/8_164.png
#   inflating: augmented/augmented/source/8_165.png
#   inflating: augmented/augmented/source/8_166.png
#   inflating: augmented/augmented/source/8_167.png
#   inflating: augmented/augmented/source/8_168.png
#   inflating: augmented/augmented/source/8_169.png
#   inflating: augmented/augmented/source/8_17.png
#   inflating: augmented/augmented/source/8_170.png
#   inflating: augmented/augmented/source/8_171.png
#   inflating: augmented/augmented/source/8_172.png
#   inflating: augmented/augmented/source/8_173.png
#   inflating: augmented/augmented/source/8_174.png
#   inflating: augmented/augmented/source/8_175.png
#   inflating: augmented/augmented/source/8_176.png
#   inflating: augmented/augmented/source/8_177.png
#   inflating: augmented/augmented/source/8_178.png
#   inflating: augmented/augmented/source/8_179.png
#   inflating: augmented/augmented/source/8_18.png
#   inflating: augmented/augmented/source/8_180.png
#   inflating: augmented/augmented/source/8_181.png
#   inflating: augmented/augmented/source/8_182.png
#   inflating: augmented/augmented/source/8_183.png
#   inflating: augmented/augmented/source/8_184.png
#   inflating: augmented/augmented/source/8_185.png
#   inflating: augmented/augmented/source/8_186.png
#   inflating: augmented/augmented/source/8_187.png
#   inflating: augmented/augmented/source/8_188.png
#   inflating: augmented/augmented/source/8_189.png
#   inflating: augmented/augmented/source/8_19.png
#   inflating: augmented/augmented/source/8_190.png
#   inflating: augmented/augmented/source/8_191.png
#   inflating: augmented/augmented/source/8_192.png
#   inflating: augmented/augmented/source/8_193.png
#   inflating: augmented/augmented/source/8_194.png
#   inflating: augmented/augmented/source/8_195.png
#   inflating: augmented/augmented/source/8_196.png
#   inflating: augmented/augmented/source/8_197.png
#   inflating: augmented/augmented/source/8_198.png
#   inflating: augmented/augmented/source/8_199.png
#   inflating: augmented/augmented/source/8_2.png
#   inflating: augmented/augmented/source/8_20.png
#   inflating: augmented/augmented/source/8_200.png
#   inflating: augmented/augmented/source/8_201.png
#   inflating: augmented/augmented/source/8_202.png
#   inflating: augmented/augmented/source/8_203.png
#   inflating: augmented/augmented/source/8_204.png
#   inflating: augmented/augmented/source/8_205.png
#   inflating: augmented/augmented/source/8_206.png
#   inflating: augmented/augmented/source/8_207.png
#   inflating: augmented/augmented/source/8_208.png
#   inflating: augmented/augmented/source/8_209.png
#   inflating: augmented/augmented/source/8_21.png
#   inflating: augmented/augmented/source/8_210.png
#   inflating: augmented/augmented/source/8_211.png
#   inflating: augmented/augmented/source/8_212.png
#   inflating: augmented/augmented/source/8_213.png
#   inflating: augmented/augmented/source/8_214.png
#   inflating: augmented/augmented/source/8_215.png
#   inflating: augmented/augmented/source/8_216.png
#   inflating: augmented/augmented/source/8_217.png
#   inflating: augmented/augmented/source/8_218.png
#   inflating: augmented/augmented/source/8_219.png
#   inflating: augmented/augmented/source/8_22.png
#   inflating: augmented/augmented/source/8_220.png
#   inflating: augmented/augmented/source/8_221.png
#   inflating: augmented/augmented/source/8_222.png
#   inflating: augmented/augmented/source/8_223.png
#   inflating: augmented/augmented/source/8_224.png
#   inflating: augmented/augmented/source/8_225.png
#   inflating: augmented/augmented/source/8_226.png
#   inflating: augmented/augmented/source/8_227.png
#   inflating: augmented/augmented/source/8_228.png
#   inflating: augmented/augmented/source/8_229.png
#   inflating: augmented/augmented/source/8_23.png
#   inflating: augmented/augmented/source/8_230.png
#   inflating: augmented/augmented/source/8_231.png
#   inflating: augmented/augmented/source/8_232.png
#   inflating: augmented/augmented/source/8_233.png
#   inflating: augmented/augmented/source/8_234.png
#   inflating: augmented/augmented/source/8_235.png
#   inflating: augmented/augmented/source/8_236.png
#   inflating: augmented/augmented/source/8_237.png
#   inflating: augmented/augmented/source/8_238.png
#   inflating: augmented/augmented/source/8_239.png
#   inflating: augmented/augmented/source/8_24.png
#   inflating: augmented/augmented/source/8_25.png
#   inflating: augmented/augmented/source/8_26.png
#   inflating: augmented/augmented/source/8_27.png
#   inflating: augmented/augmented/source/8_28.png
#   inflating: augmented/augmented/source/8_29.png
#   inflating: augmented/augmented/source/8_3.png
#   inflating: augmented/augmented/source/8_30.png
#   inflating: augmented/augmented/source/8_31.png
#   inflating: augmented/augmented/source/8_32.png
#   inflating: augmented/augmented/source/8_33.png
#   inflating: augmented/augmented/source/8_34.png
#   inflating: augmented/augmented/source/8_35.png
#   inflating: augmented/augmented/source/8_36.png
#   inflating: augmented/augmented/source/8_37.png
#   inflating: augmented/augmented/source/8_38.png
#   inflating: augmented/augmented/source/8_39.png
#   inflating: augmented/augmented/source/8_4.png
#   inflating: augmented/augmented/source/8_40.png
#   inflating: augmented/augmented/source/8_41.png
#   inflating: augmented/augmented/source/8_42.png
#   inflating: augmented/augmented/source/8_43.png
#   inflating: augmented/augmented/source/8_44.png
#   inflating: augmented/augmented/source/8_45.png
#   inflating: augmented/augmented/source/8_46.png
#   inflating: augmented/augmented/source/8_47.png
#   inflating: augmented/augmented/source/8_48.png
#   inflating: augmented/augmented/source/8_49.png
#   inflating: augmented/augmented/source/8_5.png
#   inflating: augmented/augmented/source/8_50.png
#   inflating: augmented/augmented/source/8_51.png
#   inflating: augmented/augmented/source/8_52.png
#   inflating: augmented/augmented/source/8_53.png
#   inflating: augmented/augmented/source/8_54.png
#   inflating: augmented/augmented/source/8_55.png
#   inflating: augmented/augmented/source/8_56.png
#   inflating: augmented/augmented/source/8_57.png
#   inflating: augmented/augmented/source/8_58.png
#   inflating: augmented/augmented/source/8_59.png
#   inflating: augmented/augmented/source/8_6.png
#   inflating: augmented/augmented/source/8_60.png
#   inflating: augmented/augmented/source/8_61.png
#   inflating: augmented/augmented/source/8_62.png
#   inflating: augmented/augmented/source/8_63.png
#   inflating: augmented/augmented/source/8_64.png
#   inflating: augmented/augmented/source/8_65.png
#   inflating: augmented/augmented/source/8_66.png
#   inflating: augmented/augmented/source/8_67.png
#   inflating: augmented/augmented/source/8_68.png
#   inflating: augmented/augmented/source/8_69.png
#   inflating: augmented/augmented/source/8_7.png
#   inflating: augmented/augmented/source/8_70.png
#   inflating: augmented/augmented/source/8_71.png
#   inflating: augmented/augmented/source/8_72.png
#   inflating: augmented/augmented/source/8_73.png
#   inflating: augmented/augmented/source/8_74.png
#   inflating: augmented/augmented/source/8_75.png
#   inflating: augmented/augmented/source/8_76.png
#   inflating: augmented/augmented/source/8_77.png
#   inflating: augmented/augmented/source/8_78.png
#   inflating: augmented/augmented/source/8_79.png
#   inflating: augmented/augmented/source/8_8.png
#   inflating: augmented/augmented/source/8_80.png
#   inflating: augmented/augmented/source/8_81.png
#   inflating: augmented/augmented/source/8_82.png
#   inflating: augmented/augmented/source/8_83.png
#   inflating: augmented/augmented/source/8_84.png
#   inflating: augmented/augmented/source/8_85.png
#   inflating: augmented/augmented/source/8_86.png
#   inflating: augmented/augmented/source/8_87.png
#   inflating: augmented/augmented/source/8_88.png
#   inflating: augmented/augmented/source/8_89.png
#   inflating: augmented/augmented/source/8_9.png
#   inflating: augmented/augmented/source/8_90.png
#   inflating: augmented/augmented/source/8_91.png
#   inflating: augmented/augmented/source/8_92.png
#   inflating: augmented/augmented/source/8_93.png
#   inflating: augmented/augmented/source/8_94.png
#   inflating: augmented/augmented/source/8_95.png
#   inflating: augmented/augmented/source/9_67.png
#   inflating: augmented/augmented/source/9_68.png
#   inflating: augmented/augmented/source/9_69.png
#   inflating: augmented/augmented/source/9_7.png
#   inflating: augmented/augmented/source/9_70.png
#   inflating: augmented/augmented/source/9_71.png
#   inflating: augmented/augmented/source/9_72.png
#   inflating: augmented/augmented/source/9_73.png
#   inflating: augmented/augmented/source/9_74.png
#   inflating: augmented/augmented/source/9_75.png
#   inflating: augmented/augmented/source/9_76.png
#   inflating: augmented/augmented/source/9_77.png
#   inflating: augmented/augmented/source/9_78.png
#   inflating: augmented/augmented/source/9_79.png
#   inflating: augmented/augmented/source/9_8.png
#   inflating: augmented/augmented/source/9_80.png
#   inflating: augmented/augmented/source/9_81.png
#   inflating: augmented/augmented/source/9_82.png
#   inflating: augmented/augmented/source/9_83.png
#   inflating: augmented/augmented/source/9_84.png
#   inflating: augmented/augmented/source/9_85.png
#   inflating: augmented/augmented/source/9_86.png
#   inflating: augmented/augmented/source/9_87.png
#   inflating: augmented/augmented/source/9_88.png
#   inflating: augmented/augmented/source/9_89.png
#   inflating: augmented/augmented/source/9_9.png
#   inflating: augmented/augmented/source/9_90.png
#   inflating: augmented/augmented/source/9_91.png
#   inflating: augmented/augmented/source/9_92.png
#   inflating: augmented/augmented/source/9_93.png
#   inflating: augmented/augmented/source/9_94.png
#   inflating: augmented/augmented/source/9_95.png
#   inflating: augmented/augmented/source/9_96.png
#   inflating: augmented/augmented/source/9_97.png
#   inflating: augmented/augmented/source/9_98.png
#   inflating: augmented/augmented/source/9_99.png
#   inflating: augmented/augmented/target/0_0.png
#   inflating: augmented/augmented/target/0_1.png
#   inflating: augmented/augmented/target/0_10.png
#   inflating: augmented/augmented/target/0_100.png
#   inflating: augmented/augmented/target/0_101.png
#   inflating: augmented/augmented/target/0_102.png
#   inflating: augmented/augmented/target/0_103.png
#   inflating: augmented/augmented/target/0_104.png
#   inflating: augmented/augmented/target/0_105.png
#   inflating: augmented/augmented/target/0_106.png
#   inflating: augmented/augmented/target/0_107.png
#   inflating: augmented/augmented/target/0_108.png
#   inflating: augmented/augmented/target/0_109.png
#   inflating: augmented/augmented/target/0_11.png
#   inflating: augmented/augmented/target/0_110.png
#   inflating: augmented/augmented/target/0_111.png
#   inflating: augmented/augmented/target/0_112.png
#   inflating: augmented/augmented/target/0_113.png
#   inflating: augmented/augmented/target/0_114.png
#   inflating: augmented/augmented/target/0_115.png
#   inflating: augmented/augmented/target/0_116.png
#   inflating: augmented/augmented/target/0_117.png
#   inflating: augmented/augmented/target/0_118.png
#   inflating: augmented/augmented/target/0_119.png
#   inflating: augmented/augmented/target/0_12.png
#   inflating: augmented/augmented/target/0_120.png
#   inflating: augmented/augmented/target/0_121.png
#   inflating: augmented/augmented/target/0_122.png
#   inflating: augmented/augmented/target/0_123.png
#   inflating: augmented/augmented/target/0_124.png
#   inflating: augmented/augmented/target/0_125.png
#   inflating: augmented/augmented/target/0_126.png
#   inflating: augmented/augmented/target/0_127.png
#   inflating: augmented/augmented/target/0_128.png
#   inflating: augmented/augmented/target/0_129.png
#   inflating: augmented/augmented/target/0_13.png
#   inflating: augmented/augmented/target/0_130.png
#   inflating: augmented/augmented/target/0_131.png
#   inflating: augmented/augmented/target/0_132.png
#   inflating: augmented/augmented/target/0_133.png
#   inflating: augmented/augmented/target/0_134.png
#   inflating: augmented/augmented/target/0_135.png
#   inflating: augmented/augmented/target/0_136.png
#   inflating: augmented/augmented/target/0_137.png
#   inflating: augmented/augmented/target/0_138.png
#   inflating: augmented/augmented/target/0_139.png
#   inflating: augmented/augmented/target/0_14.png
#   inflating: augmented/augmented/target/0_140.png
#   inflating: augmented/augmented/target/0_141.png
#   inflating: augmented/augmented/target/0_142.png
#   inflating: augmented/augmented/target/0_143.png
#   inflating: augmented/augmented/target/0_144.png
#   inflating: augmented/augmented/target/0_145.png
#   inflating: augmented/augmented/target/0_146.png
#   inflating: augmented/augmented/target/0_147.png
#   inflating: augmented/augmented/target/0_148.png
#   inflating: augmented/augmented/target/0_149.png
#   inflating: augmented/augmented/target/0_15.png
#   inflating: augmented/augmented/target/0_150.png
#   inflating: augmented/augmented/target/0_151.png
#   inflating: augmented/augmented/target/0_152.png
#   inflating: augmented/augmented/target/0_153.png
#   inflating: augmented/augmented/target/0_154.png
#   inflating: augmented/augmented/target/0_155.png
#   inflating: augmented/augmented/target/0_156.png
#   inflating: augmented/augmented/target/0_157.png
#   inflating: augmented/augmented/target/0_158.png
#   inflating: augmented/augmented/target/0_159.png
#   inflating: augmented/augmented/target/0_16.png
#   inflating: augmented/augmented/target/0_160.png
#   inflating: augmented/augmented/target/0_161.png
#   inflating: augmented/augmented/target/0_162.png
#   inflating: augmented/augmented/target/0_163.png
#   inflating: augmented/augmented/target/0_164.png
#   inflating: augmented/augmented/target/0_165.png
#   inflating: augmented/augmented/target/0_166.png
#   inflating: augmented/augmented/target/0_167.png
#   inflating: augmented/augmented/target/0_168.png
#   inflating: augmented/augmented/target/0_169.png
#   inflating: augmented/augmented/target/0_17.png
#   inflating: augmented/augmented/target/0_170.png
#   inflating: augmented/augmented/target/0_171.png
#   inflating: augmented/augmented/target/0_172.png
#   inflating: augmented/augmented/target/0_173.png
#   inflating: augmented/augmented/target/0_174.png
#   inflating: augmented/augmented/target/0_175.png
#   inflating: augmented/augmented/target/0_176.png
#   inflating: augmented/augmented/target/0_177.png
#   inflating: augmented/augmented/target/0_178.png
#   inflating: augmented/augmented/target/0_179.png
#   inflating: augmented/augmented/target/0_18.png
#   inflating: augmented/augmented/target/0_180.png
#   inflating: augmented/augmented/target/0_181.png
#   inflating: augmented/augmented/target/0_182.png
#   inflating: augmented/augmented/target/0_183.png
#   inflating: augmented/augmented/target/0_184.png
#   inflating: augmented/augmented/target/0_185.png
#   inflating: augmented/augmented/target/0_186.png
#   inflating: augmented/augmented/target/0_187.png
#   inflating: augmented/augmented/target/0_188.png
#   inflating: augmented/augmented/target/0_189.png
#   inflating: augmented/augmented/target/0_19.png
#   inflating: augmented/augmented/target/0_190.png
#   inflating: augmented/augmented/target/0_191.png
#   inflating: augmented/augmented/target/0_192.png
#   inflating: augmented/augmented/target/0_193.png
#   inflating: augmented/augmented/target/0_194.png
#   inflating: augmented/augmented/target/0_195.png
#   inflating: augmented/augmented/target/0_196.png
#   inflating: augmented/augmented/target/0_197.png
#   inflating: augmented/augmented/target/0_198.png
#   inflating: augmented/augmented/target/0_199.png
#   inflating: augmented/augmented/target/0_2.png
#   inflating: augmented/augmented/target/0_20.png
#   inflating: augmented/augmented/target/0_200.png
#   inflating: augmented/augmented/target/0_201.png
#   inflating: augmented/augmented/target/0_202.png
#   inflating: augmented/augmented/target/0_203.png
#   inflating: augmented/augmented/target/0_204.png
#   inflating: augmented/augmented/target/0_205.png
#   inflating: augmented/augmented/target/0_206.png
#   inflating: augmented/augmented/target/0_207.png
#   inflating: augmented/augmented/target/0_208.png
#   inflating: augmented/augmented/target/0_209.png
#   inflating: augmented/augmented/target/0_21.png
#   inflating: augmented/augmented/target/0_210.png
#   inflating: augmented/augmented/target/0_211.png
#   inflating: augmented/augmented/target/0_212.png
#   inflating: augmented/augmented/target/0_213.png
#   inflating: augmented/augmented/target/0_214.png
#   inflating: augmented/augmented/target/0_215.png
#   inflating: augmented/augmented/target/0_216.png
#   inflating: augmented/augmented/target/0_217.png
#   inflating: augmented/augmented/target/0_218.png
#   inflating: augmented/augmented/target/0_219.png
#   inflating: augmented/augmented/target/0_22.png
#   inflating: augmented/augmented/target/0_220.png
#   inflating: augmented/augmented/target/0_221.png
#   inflating: augmented/augmented/target/0_222.png
#   inflating: augmented/augmented/target/0_223.png
#   inflating: augmented/augmented/target/0_224.png
#   inflating: augmented/augmented/target/0_225.png
#   inflating: augmented/augmented/target/0_226.png
#   inflating: augmented/augmented/target/0_227.png
#   inflating: augmented/augmented/target/0_228.png
#   inflating: augmented/augmented/target/0_229.png
#   inflating: augmented/augmented/target/0_23.png
#   inflating: augmented/augmented/target/0_230.png
#   inflating: augmented/augmented/target/0_231.png
#   inflating: augmented/augmented/target/0_232.png
#   inflating: augmented/augmented/target/0_233.png
#   inflating: augmented/augmented/target/0_234.png
#   inflating: augmented/augmented/target/0_235.png
#   inflating: augmented/augmented/target/0_236.png
#   inflating: augmented/augmented/target/0_237.png
#   inflating: augmented/augmented/target/0_238.png
#   inflating: augmented/augmented/target/0_239.png
#   inflating: augmented/augmented/target/0_24.png
#   inflating: augmented/augmented/target/0_25.png
#   inflating: augmented/augmented/target/0_26.png
#   inflating: augmented/augmented/target/0_27.png
#   inflating: augmented/augmented/target/0_28.png
#   inflating: augmented/augmented/target/0_29.png
#   inflating: augmented/augmented/target/0_3.png
#   inflating: augmented/augmented/target/0_30.png
#   inflating: augmented/augmented/target/0_31.png
#   inflating: augmented/augmented/target/0_32.png
#   inflating: augmented/augmented/target/0_33.png
#   inflating: augmented/augmented/target/0_34.png
#   inflating: augmented/augmented/target/0_35.png
#   inflating: augmented/augmented/target/0_36.png
#   inflating: augmented/augmented/target/0_37.png
#   inflating: augmented/augmented/target/0_38.png
#   inflating: augmented/augmented/target/0_39.png
#   inflating: augmented/augmented/target/0_4.png
#   inflating: augmented/augmented/target/0_40.png
#   inflating: augmented/augmented/target/0_41.png
#   inflating: augmented/augmented/target/0_42.png
#   inflating: augmented/augmented/target/0_43.png
#   inflating: augmented/augmented/target/0_44.png
#   inflating: augmented/augmented/target/0_45.png
#   inflating: augmented/augmented/target/0_46.png
#   inflating: augmented/augmented/target/0_47.png
#   inflating: augmented/augmented/target/0_48.png
#   inflating: augmented/augmented/target/0_49.png
#   inflating: augmented/augmented/target/0_5.png
#   inflating: augmented/augmented/target/0_50.png
#   inflating: augmented/augmented/target/0_51.png
#   inflating: augmented/augmented/target/0_52.png
#   inflating: augmented/augmented/target/0_53.png
#   inflating: augmented/augmented/target/0_54.png
#   inflating: augmented/augmented/target/0_55.png
#   inflating: augmented/augmented/target/0_56.png
#   inflating: augmented/augmented/target/0_57.png
#   inflating: augmented/augmented/target/0_58.png
#   inflating: augmented/augmented/target/0_59.png
#   inflating: augmented/augmented/target/0_6.png
#   inflating: augmented/augmented/target/0_60.png
#   inflating: augmented/augmented/target/0_61.png
#   inflating: augmented/augmented/target/0_62.png
#   inflating: augmented/augmented/target/0_63.png
#   inflating: augmented/augmented/target/0_64.png
#   inflating: augmented/augmented/target/0_65.png
#   inflating: augmented/augmented/target/0_66.png
#   inflating: augmented/augmented/target/0_67.png
#   inflating: augmented/augmented/target/0_68.png
#   inflating: augmented/augmented/target/0_69.png
#   inflating: augmented/augmented/target/0_7.png
#   inflating: augmented/augmented/target/0_70.png
#   inflating: augmented/augmented/target/0_71.png
#   inflating: augmented/augmented/target/0_72.png
#   inflating: augmented/augmented/target/0_73.png
#   inflating: augmented/augmented/target/0_74.png
#   inflating: augmented/augmented/target/0_75.png
#   inflating: augmented/augmented/target/0_76.png
#   inflating: augmented/augmented/target/0_77.png
#   inflating: augmented/augmented/target/0_78.png
#   inflating: augmented/augmented/target/0_79.png
#   inflating: augmented/augmented/target/0_8.png
#   inflating: augmented/augmented/target/0_80.png
#   inflating: augmented/augmented/target/0_81.png
#   inflating: augmented/augmented/target/0_82.png
#   inflating: augmented/augmented/target/0_83.png
#   inflating: augmented/augmented/target/0_84.png
#   inflating: augmented/augmented/target/0_85.png
#   inflating: augmented/augmented/target/0_86.png
#   inflating: augmented/augmented/target/0_87.png
#   inflating: augmented/augmented/target/0_88.png
#   inflating: augmented/augmented/target/0_89.png
#   inflating: augmented/augmented/target/0_9.png
#   inflating: augmented/augmented/target/0_90.png
#   inflating: augmented/augmented/target/0_91.png
#   inflating: augmented/augmented/target/0_92.png
#   inflating: augmented/augmented/target/0_93.png
#   inflating: augmented/augmented/target/0_94.png
#   inflating: augmented/augmented/target/0_95.png
#   inflating: augmented/augmented/target/0_96.png
#   inflating: augmented/augmented/target/0_97.png
#   inflating: augmented/augmented/target/0_98.png
#   inflating: augmented/augmented/target/0_99.png
#   inflating: augmented/augmented/target/10_0.png
#   inflating: augmented/augmented/target/10_1.png
#   inflating: augmented/augmented/target/10_10.png
#   inflating: augmented/augmented/target/10_100.png
#   inflating: augmented/augmented/target/10_101.png
#   inflating: augmented/augmented/target/10_102.png
#   inflating: augmented/augmented/target/10_103.png
#   inflating: augmented/augmented/target/10_104.png
#   inflating: augmented/augmented/target/10_105.png
#   inflating: augmented/augmented/target/10_106.png
#   inflating: augmented/augmented/target/10_107.png
#   inflating: augmented/augmented/target/10_108.png
#   inflating: augmented/augmented/target/10_109.png
#   inflating: augmented/augmented/target/10_11.png
#   inflating: augmented/augmented/target/10_110.png
#   inflating: augmented/augmented/target/10_111.png
#   inflating: augmented/augmented/target/10_112.png
#   inflating: augmented/augmented/target/10_113.png
#   inflating: augmented/augmented/target/10_114.png
#   inflating: augmented/augmented/target/10_115.png
#   inflating: augmented/augmented/target/10_116.png
#   inflating: augmented/augmented/target/10_117.png
#   inflating: augmented/augmented/target/10_118.png
#   inflating: augmented/augmented/target/10_119.png
#   inflating: augmented/augmented/target/10_12.png
#   inflating: augmented/augmented/target/10_120.png
#   inflating: augmented/augmented/target/10_121.png
#   inflating: augmented/augmented/target/10_122.png
#   inflating: augmented/augmented/target/10_123.png
#   inflating: augmented/augmented/target/10_124.png
#   inflating: augmented/augmented/target/10_125.png
#   inflating: augmented/augmented/target/10_126.png
#   inflating: augmented/augmented/target/10_127.png
#   inflating: augmented/augmented/target/10_128.png
#   inflating: augmented/augmented/target/10_129.png
#   inflating: augmented/augmented/target/10_13.png
#   inflating: augmented/augmented/target/10_130.png
#   inflating: augmented/augmented/target/10_131.png
#   inflating: augmented/augmented/target/10_132.png
#   inflating: augmented/augmented/target/10_133.png
#   inflating: augmented/augmented/target/10_134.png
#   inflating: augmented/augmented/target/10_135.png
#   inflating: augmented/augmented/target/10_136.png
#   inflating: augmented/augmented/target/10_137.png
#   inflating: augmented/augmented/target/10_138.png
#   inflating: augmented/augmented/target/10_139.png
#   inflating: augmented/augmented/target/10_14.png
#   inflating: augmented/augmented/target/10_140.png
#   inflating: augmented/augmented/target/10_141.png
#   inflating: augmented/augmented/target/10_142.png
#   inflating: augmented/augmented/target/10_143.png
#   inflating: augmented/augmented/target/10_144.png
#   inflating: augmented/augmented/target/10_145.png
#   inflating: augmented/augmented/target/10_146.png
#   inflating: augmented/augmented/target/10_147.png
#   inflating: augmented/augmented/target/10_148.png
#   inflating: augmented/augmented/target/10_149.png
#   inflating: augmented/augmented/target/10_15.png
#   inflating: augmented/augmented/target/10_150.png
#   inflating: augmented/augmented/target/10_151.png
#   inflating: augmented/augmented/target/10_152.png
#   inflating: augmented/augmented/target/10_153.png
#   inflating: augmented/augmented/target/10_154.png
#   inflating: augmented/augmented/target/10_155.png
#   inflating: augmented/augmented/target/10_156.png
#   inflating: augmented/augmented/target/10_157.png
#   inflating: augmented/augmented/target/10_158.png
#   inflating: augmented/augmented/target/10_159.png
#   inflating: augmented/augmented/target/10_16.png
#   inflating: augmented/augmented/target/10_160.png
#   inflating: augmented/augmented/target/10_161.png
#   inflating: augmented/augmented/target/10_162.png
#   inflating: augmented/augmented/target/10_163.png
#   inflating: augmented/augmented/target/10_164.png
#   inflating: augmented/augmented/target/10_165.png
#   inflating: augmented/augmented/target/10_166.png
#   inflating: augmented/augmented/target/10_167.png
#   inflating: augmented/augmented/target/10_168.png
#   inflating: augmented/augmented/target/10_169.png
#   inflating: augmented/augmented/target/10_17.png
#   inflating: augmented/augmented/target/10_170.png
#   inflating: augmented/augmented/target/10_171.png
#   inflating: augmented/augmented/target/10_172.png
#   inflating: augmented/augmented/target/10_173.png
#   inflating: augmented/augmented/target/10_174.png
#   inflating: augmented/augmented/target/10_175.png
#   inflating: augmented/augmented/target/10_176.png
#   inflating: augmented/augmented/target/10_177.png
#   inflating: augmented/augmented/target/10_178.png
#   inflating: augmented/augmented/target/10_179.png
#   inflating: augmented/augmented/target/10_18.png
#   inflating: augmented/augmented/target/10_180.png
#   inflating: augmented/augmented/target/10_181.png
#   inflating: augmented/augmented/target/10_182.png
#   inflating: augmented/augmented/target/10_183.png
#   inflating: augmented/augmented/target/10_184.png
#   inflating: augmented/augmented/target/10_185.png
#   inflating: augmented/augmented/target/10_186.png
#   inflating: augmented/augmented/target/10_187.png
#   inflating: augmented/augmented/target/10_188.png
#   inflating: augmented/augmented/target/10_189.png
#   inflating: augmented/augmented/target/10_19.png
#   inflating: augmented/augmented/target/10_190.png
#   inflating: augmented/augmented/target/10_191.png
#   inflating: augmented/augmented/target/10_192.png
#   inflating: augmented/augmented/target/10_193.png
#   inflating: augmented/augmented/target/10_194.png
#   inflating: augmented/augmented/target/10_195.png
#   inflating: augmented/augmented/target/10_196.png
#   inflating: augmented/augmented/target/10_197.png
#   inflating: augmented/augmented/target/10_198.png
#   inflating: augmented/augmented/target/10_199.png
#   inflating: augmented/augmented/target/10_2.png
#   inflating: augmented/augmented/target/10_20.png
#   inflating: augmented/augmented/target/10_200.png
#   inflating: augmented/augmented/target/10_201.png
#   inflating: augmented/augmented/target/10_202.png
#   inflating: augmented/augmented/target/10_203.png
#   inflating: augmented/augmented/target/10_204.png
#   inflating: augmented/augmented/target/10_205.png
#   inflating: augmented/augmented/target/10_206.png
#   inflating: augmented/augmented/target/10_207.png
#   inflating: augmented/augmented/target/10_208.png
#   inflating: augmented/augmented/target/10_209.png
#   inflating: augmented/augmented/target/10_21.png
#   inflating: augmented/augmented/target/10_210.png
#   inflating: augmented/augmented/target/10_211.png
#   inflating: augmented/augmented/target/10_212.png
#   inflating: augmented/augmented/target/10_213.png
#   inflating: augmented/augmented/target/10_214.png
#   inflating: augmented/augmented/target/10_215.png
#   inflating: augmented/augmented/target/10_216.png
#   inflating: augmented/augmented/target/10_217.png
#   inflating: augmented/augmented/target/10_218.png
#   inflating: augmented/augmented/target/10_219.png
#   inflating: augmented/augmented/target/10_22.png
#   inflating: augmented/augmented/target/10_220.png
#   inflating: augmented/augmented/target/10_221.png
#   inflating: jsrt/JSRT/JPCLN061.png
#   inflating: jsrt/JSRT/JPCLN062.png
#   inflating: jsrt/JSRT/JPCLN063.png
#   inflating: jsrt/JSRT/JPCLN064.png
#   inflating: jsrt/JSRT/JPCLN065.png
#   inflating: jsrt/JSRT/JPCLN066.png
#   inflating: jsrt/JSRT/JPCLN067.png
#   inflating: jsrt/JSRT/JPCLN068.png
#   inflating: jsrt/JSRT/JPCLN069.png
#   inflating: jsrt/JSRT/JPCLN070.png
#   inflating: jsrt/JSRT/JPCLN071.png
#   inflating: jsrt/JSRT/JPCLN072.png
#   inflating: jsrt/JSRT/JPCLN073.png
#   inflating: jsrt/JSRT/JPCLN074.png
#   inflating: jsrt/JSRT/JPCLN075.png
#   inflating: jsrt/JSRT/JPCLN076.png
#   inflating: jsrt/JSRT/JPCLN077.png
#   inflating: jsrt/JSRT/JPCLN079.png
#   inflating: jsrt/JSRT/JPCLN080.png
#   inflating: jsrt/JSRT/JPCLN081.png
#   inflating: jsrt/JSRT/JPCLN082.png
#   inflating: jsrt/JSRT/JPCLN084.png
#   inflating: jsrt/JSRT/JPCLN085.png
#   inflating: jsrt/JSRT/JPCLN086.png
#   inflating: jsrt/JSRT/JPCLN087.png
#   inflating: jsrt/JSRT/JPCLN088.png
#   inflating: jsrt/JSRT/JPCLN089.png
#   inflating: jsrt/JSRT/JPCLN090.png
#   inflating: jsrt/JSRT/JPCLN091.png
#   inflating: jsrt/JSRT/JPCLN092.png
#   inflating: jsrt/JSRT/JPCLN093.png
#   inflating: jsrt/JSRT/JPCLN095.png
#   inflating: jsrt/JSRT/JPCLN096.png
#   inflating: jsrt/JSRT/JPCLN097.png
#   inflating: jsrt/JSRT/JPCLN098.png
#   inflating: jsrt/JSRT/JPCLN099.png
#   inflating: jsrt/JSRT/JPCLN100.png
#   inflating: jsrt/JSRT/JPCLN101.png
#   inflating: jsrt/JSRT/JPCLN102.png
#   inflating: jsrt/JSRT/JPCLN103.png
#   inflating: jsrt/JSRT/JPCLN104.png
#   inflating: jsrt/JSRT/JPCLN105.png
#   inflating: jsrt/JSRT/JPCLN106.png
#   inflating: jsrt/JSRT/JPCLN107.png
#   inflating: jsrt/JSRT/JPCLN108.png
#   inflating: jsrt/JSRT/JPCLN109.png
#   inflating: jsrt/JSRT/JPCLN110.png
#   inflating: jsrt/JSRT/JPCLN111.png
#   inflating: jsrt/JSRT/JPCLN112.png
#   inflating: jsrt/JSRT/JPCLN113.png
#   inflating: jsrt/JSRT/JPCLN114.png
#   inflating: jsrt/JSRT/JPCLN115.png
#   inflating: jsrt/JSRT/JPCLN116.png
#   inflating: jsrt/JSRT/JPCLN118.png
#   inflating: jsrt/JSRT/JPCLN119.png
#   inflating: jsrt/JSRT/JPCLN120.png
#   inflating: jsrt/JSRT/JPCLN121.png
#   inflating: jsrt/JSRT/JPCLN123.png
#   inflating: jsrt/JSRT/JPCLN124.png
#   inflating: jsrt/JSRT/JPCLN125.png
#   inflating: jsrt/JSRT/JPCLN126.png
#   inflating: jsrt/JSRT/JPCLN127.png
#   inflating: jsrt/JSRT/JPCLN128.png
#   inflating: jsrt/JSRT/JPCLN129.png
#   inflating: jsrt/JSRT/JPCLN130.png
#   inflating: jsrt/JSRT/JPCLN131.png
#   inflating: jsrt/JSRT/JPCLN132.png
#   inflating: jsrt/JSRT/JPCLN133.png
#   inflating: jsrt/JSRT/JPCLN134.png
#   inflating: jsrt/JSRT/JPCLN135.png
#   inflating: jsrt/JSRT/JPCLN136.png
#   inflating: jsrt/JSRT/JPCLN137.png
#   inflating: jsrt/JSRT/JPCLN138.png
#   inflating: jsrt/JSRT/JPCLN139.png
#   inflating: jsrt/JSRT/JPCLN140.png
#   inflating: jsrt/JSRT/JPCLN141.png
#   inflating: jsrt/JSRT/JPCLN142.png
#   inflating: jsrt/JSRT/JPCLN143.png
#   inflating: jsrt/JSRT/JPCLN144.png
#   inflating: jsrt/JSRT/JPCLN145.png
#   inflating: jsrt/JSRT/JPCLN146.png
#   inflating: jsrt/JSRT/JPCLN147.png
#   inflating: jsrt/JSRT/JPCLN148.png
#   inflating: jsrt/JSRT/JPCLN149.png
#   inflating: jsrt/JSRT/JPCLN150.png
#   inflating: jsrt/JSRT/JPCLN151.png
#   inflating: jsrt/JSRT/JPCLN152.png
#   inflating: jsrt/JSRT/JPCLN153.png
#   inflating: jsrt/JSRT/JPCLN154.png
#   inflating: jsrt/JSRT/JPCNN001.png
#   inflating: jsrt/JSRT/JPCNN002.png
#   inflating: jsrt/JSRT/JPCNN003.png
#   inflating: jsrt/JSRT/JPCNN004.png
#   inflating: jsrt/JSRT/JPCNN005.png
#   inflating: jsrt/JSRT/JPCNN006.png
#   inflating: jsrt/JSRT/JPCNN007.png
#   inflating: jsrt/JSRT/JPCNN008.png
#   inflating: jsrt/JSRT/JPCNN009.png
#   inflating: jsrt/JSRT/JPCNN010.png
#   inflating: jsrt/JSRT/JPCNN011.png
#   inflating: jsrt/JSRT/JPCNN012.png
#   inflating: jsrt/JSRT/JPCNN013.png
#   inflating: jsrt/JSRT/JPCNN014.png
#   inflating: jsrt/JSRT/JPCNN015.png
#   inflating: jsrt/JSRT/JPCNN016.png
#   inflating: jsrt/JSRT/JPCNN017.png
#   inflating: jsrt/JSRT/JPCNN018.png
#   inflating: jsrt/JSRT/JPCNN019.png
#   inflating: jsrt/JSRT/JPCNN020.png
#   inflating: jsrt/JSRT/JPCNN021.png
#   inflating: jsrt/JSRT/JPCNN022.png
#   inflating: jsrt/JSRT/JPCNN023.png
#   inflating: jsrt/JSRT/JPCNN024.png
#   inflating: jsrt/JSRT/JPCNN025.png
#   inflating: jsrt/JSRT/JPCNN026.png
#   inflating: jsrt/JSRT/JPCNN027.png
#   inflating: jsrt/JSRT/JPCNN028.png
#   inflating: jsrt/JSRT/JPCNN029.png
#   inflating: jsrt/JSRT/JPCNN030.png
#   inflating: jsrt/JSRT/JPCNN031.png
#   inflating: jsrt/JSRT/JPCNN032.png
#   inflating: jsrt/JSRT/JPCNN033.png
#   inflating: jsrt/JSRT/JPCNN034.png
#   inflating: jsrt/JSRT/JPCNN035.png
#   inflating: jsrt/JSRT/JPCNN036.png
#   inflating: jsrt/JSRT/JPCNN037.png
#   inflating: jsrt/JSRT/JPCNN038.png
#   inflating: jsrt/JSRT/JPCNN039.png
#   inflating: jsrt/JSRT/JPCNN040.png
#   inflating: jsrt/JSRT/JPCNN041.png
#   inflating: jsrt/JSRT/JPCNN042.png
#   inflating: jsrt/JSRT/JPCNN043.png
#   inflating: jsrt/JSRT/JPCNN044.png
#   inflating: jsrt/JSRT/JPCNN045.png
#   inflating: jsrt/JSRT/JPCNN046.png
#   inflating: jsrt/JSRT/JPCNN047.png
#   inflating: jsrt/JSRT/JPCNN048.png
#   inflating: jsrt/JSRT/JPCNN049.png
#   inflating: jsrt/JSRT/JPCNN050.png
#   inflating: jsrt/JSRT/JPCNN051.png
#   inflating: jsrt/JSRT/JPCNN052.png
#   inflating: jsrt/JSRT/JPCNN053.png
#   inflating: jsrt/JSRT/JPCNN054.png
#   inflating: jsrt/JSRT/JPCNN055.png
#   inflating: jsrt/JSRT/JPCNN056.png
#   inflating: jsrt/JSRT/JPCNN057.png
#   inflating: jsrt/JSRT/JPCNN058.png
#   inflating: jsrt/JSRT/JPCNN059.png
#   inflating: jsrt/JSRT/JPCNN060.png
#   inflating: jsrt/JSRT/JPCNN061.png
#   inflating: jsrt/JSRT/JPCNN062.png
#   inflating: jsrt/JSRT/JPCNN063.png
#   inflating: jsrt/JSRT/JPCNN064.png
#   inflating: jsrt/JSRT/JPCNN065.png
#   inflating: jsrt/JSRT/JPCNN066.png
#   inflating: jsrt/JSRT/JPCNN067.png
#   inflating: jsrt/JSRT/JPCNN068.png
#   inflating: jsrt/JSRT/JPCNN069.png
#   inflating: jsrt/JSRT/JPCNN070.png
#   inflating: jsrt/JSRT/JPCNN071.png
#   inflating: jsrt/JSRT/JPCNN072.png
#   inflating: jsrt/JSRT/JPCNN073.png
#   inflating: jsrt/JSRT/JPCNN074.png
#   inflating: jsrt/JSRT/JPCNN075.png
#   inflating: jsrt/JSRT/JPCNN076.png
#   inflating: jsrt/JSRT/JPCNN077.png
#   inflating: jsrt/JSRT/JPCNN078.png
#   inflating: jsrt/JSRT/JPCNN079.png
#   inflating: jsrt/JSRT/JPCNN080.png
#   inflating: jsrt/JSRT/JPCNN081.png
#   inflating: jsrt/JSRT/JPCNN082.png
#   inflating: jsrt/JSRT/JPCNN083.png
#   inflating: jsrt/JSRT/JPCNN084.png
#   inflating: jsrt/JSRT/JPCNN085.png
#   inflating: jsrt/JSRT/JPCNN086.png
#   inflating: jsrt/JSRT/JPCNN087.png
#   inflating: jsrt/JSRT/JPCNN088.png
#   inflating: jsrt/JSRT/JPCNN089.png
#   inflating: jsrt/JSRT/JPCNN090.png
#   inflating: jsrt/JSRT/JPCNN091.png
#   inflating: jsrt/JSRT/JPCNN092.png
#   inflating: jsrt/JSRT/JPCNN093.png

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.models import Sequential

import numpy as np
import matplotlib.pyplot as plt

import os
import cv2
from keras.preprocessing.image import img_to_array

# x is noisy data and y is clean data
SIZE = 256

from tqdm import tqdm
noisy_data=[]
path1 = 'augmented/augmented/source'
files=os.listdir(path1)
for i in tqdm(files):
    img=cv2.imread(path1+'/'+i,0)   #Change 0 to 1 for color images
    img=cv2.resize(img,(SIZE, SIZE))
    noisy_data.append(img_to_array(img))
    

clean_data=[]
path2 = 'augmented/augmented/target'
files=os.listdir(path2)
for i in tqdm(files):
    img=cv2.imread(path2+'/'+i,0)  #Change 0 to 1 for color images
    img=cv2.resize(img,(SIZE, SIZE))
    clean_data.append(img_to_array(img))

noisy_train = np.reshape(noisy_data, (len(noisy_data), SIZE, SIZE, 1))
noisy_train = noisy_train.astype('float32') / 255.

clean_train = np.reshape(clean_data, (len(clean_data), SIZE, SIZE, 1))
clean_train = clean_train.astype('float32') / 255.


#Displaying images with noise
plt.figure(figsize=(10, 2))
for i in range(1,4):
    ax = plt.subplot(1, 4, i)
    plt.imshow(noisy_train[i].reshape(SIZE, SIZE), cmap="binary")
plt.show()

#Displaying clean images
plt.figure(figsize=(10, 2))
for i in range(1,4):
    ax = plt.subplot(1, 4, i)
    plt.imshow(clean_train[i].reshape(SIZE, SIZE), cmap="binary")
plt.show()



model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(SIZE, SIZE, 1)))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
 

model.add(MaxPooling2D((2, 2), padding='same'))
     
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(1, (3, 3), activation='relu', padding='same'))

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

model.summary()

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(noisy_train, clean_train, 
                                                    test_size = 0.20, random_state = 0)


model.fit(x_train, y_train, epochs=100, batch_size=8, shuffle=True, verbose = 1,
          validation_split = 0.1)


print("Test_Accuracy: {:.2f}%".format(model.evaluate(np.array(x_test), np.array(y_test))[1]*100))


model.save('Bonesupression_autoencoder.model')

no_noise_img = model.predict(x_test)


plt.imshow(no_noise_img[i].reshape(SIZE,SIZE), cmap="gray")
#plt.imsave('sandstone/denoised_images/denoised_image.tif', no_noise_img[3].reshape(SIZE,SIZE))

"""
plt.figure(figsize=(40, 4))
for i in range(10):
    # display original
    ax = plt.subplot(3, 20, i + 1)
    plt.imshow(y_test[i].reshape(SIZE,SIZE), cmap="gray")
    
    # display reconstructed (after noise removed) image
    ax = plt.subplot(3, 20, 40 +i+ 1)
    plt.imshow(no_noise_img[i].reshape(SIZE,SIZE), cmap="gray")
plt.show()
"""
# Out:
# 100%|██████████| 4080/4080 [00:39<00:00, 103.21it/s]
# 100%|██████████| 4080/4080 [00:39<00:00, 104.60it/s]
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_28 (Conv2D)           (None, 256, 256, 32)      320
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 128, 128, 8)       2312
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 64, 64, 8)         0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 64, 64, 8)         584
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 32, 32, 8)         0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 32, 32, 8)         584
# _________________________________________________________________
# up_sampling2d_12 (UpSampling (None, 64, 64, 8)         0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 64, 64, 8)         584
# _________________________________________________________________
# up_sampling2d_13 (UpSampling (None, 128, 128, 8)       0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 128, 128, 32)      2336
# _________________________________________________________________
# up_sampling2d_14 (UpSampling (None, 256, 256, 32)      0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 256, 256, 1)       289
# =================================================================
# Total params: 7,009
# Trainable params: 7,009
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 368/368 [==============================] - 9s 23ms/step - loss: 0.0113 - accuracy: 0.1064 - val_loss: 0.0027 - val_accuracy: 0.1065
# Epoch 2/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0021 - accuracy: 0.1060 - val_loss: 0.0019 - val_accuracy: 0.1067
# Epoch 3/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0017 - accuracy: 0.1066 - val_loss: 0.0017 - val_accuracy: 0.1067
# Epoch 4/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0016 - accuracy: 0.1064 - val_loss: 0.0020 - val_accuracy: 0.1068
# Epoch 5/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0015 - accuracy: 0.1064 - val_loss: 0.0018 - val_accuracy: 0.1067
# Epoch 6/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0014 - accuracy: 0.1056 - val_loss: 0.0015 - val_accuracy: 0.1068
# Epoch 7/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0014 - accuracy: 0.1059 - val_loss: 0.0015 - val_accuracy: 0.1068
# Epoch 8/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0013 - accuracy: 0.1058 - val_loss: 0.0015 - val_accuracy: 0.1068
# Epoch 9/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0013 - accuracy: 0.1073 - val_loss: 0.0015 - val_accuracy: 0.1067
# Epoch 10/100
# 368/368 [==============================] - 8s 23ms/step - loss: 0.0013 - accuracy: 0.1044 - val_loss: 0.0021 - val_accuracy: 0.1068
# Epoch 11/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0014 - accuracy: 0.1059 - val_loss: 0.0014 - val_accuracy: 0.1068
# Epoch 12/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0013 - accuracy: 0.1072 - val_loss: 0.0014 - val_accuracy: 0.1068
# Epoch 13/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0013 - accuracy: 0.1074 - val_loss: 0.0015 - val_accuracy: 0.1067
# Epoch 14/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0013 - accuracy: 0.1070 - val_loss: 0.0013 - val_accuracy: 0.1068
# Epoch 15/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0012 - accuracy: 0.1054 - val_loss: 0.0014 - val_accuracy: 0.1067
# Epoch 16/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0013 - accuracy: 0.1058 - val_loss: 0.0025 - val_accuracy: 0.1068
# Epoch 17/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0014 - accuracy: 0.1048 - val_loss: 0.0013 - val_accuracy: 0.1068
# Epoch 18/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0012 - accuracy: 0.1057 - val_loss: 0.0015 - val_accuracy: 0.1068
# Epoch 19/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0012 - accuracy: 0.1072 - val_loss: 0.0014 - val_accuracy: 0.1068
# Epoch 20/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0012 - accuracy: 0.1075 - val_loss: 0.0013 - val_accuracy: 0.1068
# Epoch 21/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0012 - accuracy: 0.1078 - val_loss: 0.0013 - val_accuracy: 0.1068
# Epoch 22/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1073 - val_loss: 0.0013 - val_accuracy: 0.1068
# Epoch 23/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0012 - accuracy: 0.1072 - val_loss: 0.0013 - val_accuracy: 0.1068
# Epoch 24/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0012 - accuracy: 0.1068 - val_loss: 0.0015 - val_accuracy: 0.1068
# Epoch 25/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0012 - accuracy: 0.1068 - val_loss: 0.0014 - val_accuracy: 0.1068
# Epoch 26/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0012 - accuracy: 0.1060 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 27/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1067 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 28/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1061 - val_loss: 0.0013 - val_accuracy: 0.1068
# Epoch 29/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0012 - accuracy: 0.1057 - val_loss: 0.0015 - val_accuracy: 0.1068
# Epoch 30/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1067 - val_loss: 0.0013 - val_accuracy: 0.1068
# Epoch 31/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0012 - accuracy: 0.1075 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 32/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0012 - accuracy: 0.1073 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 33/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0012 - accuracy: 0.1069 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 34/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1063 - val_loss: 0.0014 - val_accuracy: 0.1068
# Epoch 35/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1069 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 36/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0012 - accuracy: 0.1059 - val_loss: 0.0015 - val_accuracy: 0.1068
# Epoch 37/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1069 - val_loss: 0.0013 - val_accuracy: 0.1068
# Epoch 38/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1065 - val_loss: 0.0013 - val_accuracy: 0.1068
# Epoch 39/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1057 - val_loss: 0.0013 - val_accuracy: 0.1068
# Epoch 40/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1049 - val_loss: 0.0014 - val_accuracy: 0.1068
# Epoch 41/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1060 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 42/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1063 - val_loss: 0.0019 - val_accuracy: 0.1068
# Epoch 43/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0012 - accuracy: 0.1061 - val_loss: 0.0014 - val_accuracy: 0.1068
# Epoch 44/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1069 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 45/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1050 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 46/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1048 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 47/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1063 - val_loss: 0.0013 - val_accuracy: 0.1068
# Epoch 48/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1074 - val_loss: 0.0013 - val_accuracy: 0.1068
# Epoch 49/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1061 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 50/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0010 - accuracy: 0.1062 - val_loss: 0.0013 - val_accuracy: 0.1068
# Epoch 51/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1053 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 52/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1071 - val_loss: 0.0013 - val_accuracy: 0.1068
# Epoch 53/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1045 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 54/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1062 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 55/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0010 - accuracy: 0.1060 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 56/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1062 - val_loss: 0.0013 - val_accuracy: 0.1067
# Epoch 57/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1066 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 58/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1063 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 59/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1050 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 60/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1056 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 61/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1062 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 62/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0010 - accuracy: 0.1071 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 63/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1056 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 64/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0010 - accuracy: 0.1066 - val_loss: 0.0015 - val_accuracy: 0.1068
# Epoch 65/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1067 - val_loss: 0.0013 - val_accuracy: 0.1068
# Epoch 66/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0010 - accuracy: 0.1059 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 67/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1064 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 68/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0010 - accuracy: 0.1072 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 69/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0010 - accuracy: 0.1071 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 70/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0010 - accuracy: 0.1073 - val_loss: 0.0011 - val_accuracy: 0.1068
# Epoch 71/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0010 - accuracy: 0.1072 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 72/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1060 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 73/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0010 - accuracy: 0.1057 - val_loss: 0.0013 - val_accuracy: 0.1068
# Epoch 74/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1056 - val_loss: 0.0013 - val_accuracy: 0.1068
# Epoch 75/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1066 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 76/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0010 - accuracy: 0.1067 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 77/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0010 - accuracy: 0.1065 - val_loss: 0.0011 - val_accuracy: 0.1068
# Epoch 78/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0010 - accuracy: 0.1054 - val_loss: 0.0011 - val_accuracy: 0.1068
# Epoch 79/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0010 - accuracy: 0.1067 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 80/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0010 - accuracy: 0.1062 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 81/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0010 - accuracy: 0.1071 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 82/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0010 - accuracy: 0.1076 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 83/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0010 - accuracy: 0.1055 - val_loss: 0.0015 - val_accuracy: 0.1067
# Epoch 84/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1073 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 85/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1074 - val_loss: 0.0011 - val_accuracy: 0.1068
# Epoch 86/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0010 - accuracy: 0.1056 - val_loss: 0.0014 - val_accuracy: 0.1068
# Epoch 87/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0010 - accuracy: 0.1061 - val_loss: 0.0014 - val_accuracy: 0.1067
# Epoch 88/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0010 - accuracy: 0.1061 - val_loss: 0.0011 - val_accuracy: 0.1068
# Epoch 89/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0010 - accuracy: 0.1068 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 90/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0010 - accuracy: 0.1061 - val_loss: 0.0011 - val_accuracy: 0.1068
# Epoch 91/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0010 - accuracy: 0.1068 - val_loss: 0.0011 - val_accuracy: 0.1068
# Epoch 92/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0010 - accuracy: 0.1053 - val_loss: 0.0013 - val_accuracy: 0.1068
# Epoch 93/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1045 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 94/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0010 - accuracy: 0.1066 - val_loss: 0.0012 - val_accuracy: 0.1068
# Epoch 95/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0010 - accuracy: 0.1060 - val_loss: 0.0011 - val_accuracy: 0.1068
# Epoch 96/100
# 368/368 [==============================] - 8s 22ms/step - loss: 9.6314e-04 - accuracy: 0.1049 - val_loss: 0.0011 - val_accuracy: 0.1068
# Epoch 97/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0010 - accuracy: 0.1079 - val_loss: 0.0011 - val_accuracy: 0.1068
# Epoch 98/100
# 368/368 [==============================] - 8s 22ms/step - loss: 9.9551e-04 - accuracy: 0.1062 - val_loss: 0.0011 - val_accuracy: 0.1068
# Epoch 99/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0010 - accuracy: 0.1067 - val_loss: 0.0011 - val_accuracy: 0.1068
# Epoch 100/100
# 368/368 [==============================] - 8s 22ms/step - loss: 0.0011 - accuracy: 0.1061 - val_loss: 0.0014 - val_accuracy: 0.1068
# 26/26 [==============================] - 1s 37ms/step - loss: 0.0013 - accuracy: 0.1035
# Test_Accuracy: 10.35%
# INFO:tensorflow:Assets written to: Bonesupression_autoencoder.model/assets
# '\nplt.figure(figsize=(40, 4))\nfor i in range(10):\n    # display original\n    ax = plt.subplot(3, 20, i + 1)\n    plt.imshow(y_test[i].reshape(SIZE,SIZE), cmap="gray")\n    \n    # display reconstructed (after noise removed) image\n    ax = plt.subplot(3, 20, 40 +i+ 1)\n    plt.imshow(no_noise_img[i].reshape(SIZE,SIZE), cmap="gray")\nplt.show()\n'

# %%
import cv2
import matplotlib.pyplot as plt
img=cv2.imread("COVID (1185).png",0)
img1=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#edges=cv2.Laplacian(img,-1,ksize=1,delta=0,borderType=cv2.BORDER_DEFAULT)
edgex=cv2.Sobel(log_image,-1,dx=1,dy=0,ksize=3,delta=0,borderType=cv2.BORDER_DEFAULT)
edgey=cv2.Sobel(img1,-1,dx=0,dy=1,ksize=1,delta=0,borderType=cv2.BORDER_DEFAULT)
#edges=edgex+edgey
edges = cv2.cvtColor(edgex, cv2.COLOR_BGR2GRAY)

ret2,th2 = cv2.threshold(edgex,25,255,cv2.THRESH_BINARY)
plt.imshow(th2)
plt.xticks([])
plt.yticks([])
# Out:
# ([], <a list of 0 Text major ticklabel objects>)

# %%
import cv2 
import numpy as np 
import matplotlib.pyplot as plt 

# Read an image 
image = cv2.imread('COVID (1193).png') 

# Apply log transformation method 
c = 270 / np.log(1 + np.max(image)) 
log_image = c * (np.log(image + 1)) 

# Specify the data type so that 
# float value will be converted to int 
log_image = np.array(log_image, dtype = np.uint8) 

# Display both images 
plt.imshow(image) 
plt.show() 
plt.imshow(log_image) 
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: RuntimeWarning: divide by zero encountered in log
#   # Remove the CWD from sys.path while we load stuff.
